# %%
##Write a Python program to reverse a tuple 
x = (1,3,5,6,8)
result = reversed(x)
result = tuple(result)
print(result)
# Out:
# (8, 6, 5, 3, 1)

# %%
#Write a Python program to convert a list to a tuple.
f = [5,6,7,8]
f = tuple(f)

# %%
#Write a Python program to replace last value of tuples in a list.
c = ([5,6,7],[20,40,7])
for i in c:
  print(i[:-1] + [100,])
# Out:
# [5, 6, 100]
# [20, 40, 100]

# %%
#Write a Python program to find the repeated items of a tuple.
v = (4,5,6,5,5,3)
v.count(5)
# Out:
# 3

# %%
#Write a Python program to remove an empty tuple(s) from a list of tuples.
l = [(),(),(1,2),(4)]
l = [i for i in l if i]
print(l)
# Out:
# [(1, 2), 4]

# %%
#Write a Python program to unzip a list of tuples into individual lists.
l = [(1,2),(3,4),(5,6)]
print(list(zip(*l)))
# Out:
# [(1, 3, 5), (2, 4, 6)]

# %%
#Write a Python program to convert a list of tuples into a dictionary.
l = [('a',1),('b',2),('c',3)]
result = l
result = dict(result)
print(result)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
#How will you create a dictionary using tuples in python?
h = {}
h.setdefault("name")
h
# Out:
# {'name': None}

# %%
#Write a Python script to sort (ascending and descending) a dictionary by value.
import operator
h1 = {1:2,3:4,5:6,7:8}
sg = sorted(h1.items() , key=operator.itemgetter(1))
print(sg)
s1 = dict(sorted(h1.items() , key=operator.itemgetter(1) , reverse=True))
print(s1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-11d1e7925a6d> in <module>()
#       2 import operator
#       3 h1 = {1:2,3:4,5:6,7:8}
# ----> 4 sg = sorted(h1.items() , key=operator.itemgetter(1))
#       5 print(sg)
#       6 s1 = dict(sorted(h1.items() , key=operator.itemgetter(1) , reverse=True))
#
# TypeError: 'list' object is not callable

# %%
#Write a Python script to concatenate following dictionaries to create a new one.
d1 = {1:2,3:5}
d2 = {2:6,7:7}
d3 = {3:1,2:9}
d4 = {}
for i in (d1,d2,d3): 
  d4.update(i)
  print(d4)
# Out:
# {1: 2, 3: 5}
# {1: 2, 3: 5, 2: 6, 7: 7}
# {1: 2, 3: 1, 2: 9, 7: 7}

# %%
  #Write a Python script to check if a given key already exists in a dictionary.
d = {1:2,3:5,4:5,6:7,8:9}
def is_key_present(i):
    if i in d:
      print("present in dict")
    else:
      print("not present in dict")

is_key_present(1)
is_key_present(45)
# Out:
# present in dict
# not present in dict

# %%
#How Do You Traverse Through A Dictionary Object In Python?

d = {"name":"roman","city":"surat"}
d.keys()
# Out:
# dict_keys(['name', 'city'])

# %%
#How Do You Check The Presence Of A Key In A Dictionary?

# %%
#Write a Python script to print a dictionary where the keys are numbers between 1 and 15.
d = dict()
for i in range(1,16):
  d[i]=i**2
  print(d)
# Out:
# {1: 1}
# {1: 1, 2: 4}
# {1: 1, 2: 4, 3: 9}
# {1: 1, 2: 4, 3: 9, 4: 16}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196}
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
#Write a Python program to check multiple keys exists in a dictionary
l = {"name":"roman","city":"surat","class":"a"}
print(l.keys() >= {"name" , "city"})
print(l.keys() >= {"name" , "surat"})
# Out:
# True
# False

# %%
#Write a Python script to merge two Python dictionaries
d1 = {"name":"roman"}
d2 = {"city":"surat"}
d = d1.copy()
d.update(d2)
print(d)
# Out:
# {'name': 'roman', 'city': 'surat'}

# %%
#Write a Python program to map two lists into a dictionary
name = ["roman","ajay"]
city = ["surat","mumbai"]
map = dict(zip(name,city))
print(map)
# Out:
# {'roman': 'surat', 'ajay': 'mumbai'}

# %%
#Write a Python program to combine two dictionary adding values for common keys.
dict1 = {'a': 100, 'b': 200, 'c':300}
dict2 = {'a': 300, 'b': 200,'d':400}
for i in dict2:
  if i in dict1:
    dict2[i] = dict2[i] + dict1[i]
  else:
    pass
print(dict2)
# Out:
# {'a': 400, 'b': 400, 'd': 400}

# %%
#Write a Python program to print all unique values in a dictionary.
g = [{"name":"roman"},{"city":"surat"},{"pincode":1234}]
print("öriganal dict",g)
u_value = set(val for i in g for val in i.values())
print(u_value)
# Out:
# öriganal dict [{'name': 'roman'}, {'city': 'surat'}, {'pincode': 1234}]
# {'surat', 1234, 'roman'}

# %%
#Why Do You Use the Zip () Method in Python?
'''creates an iterator that will aggregate elements from two or more iterables. '''
# Out:
# 'creates an iterator that will aggregate elements from two or more iterables. '

# %%
'''Write a Python program to create and display all combinations of letters, selecting each letter from a different key in a dictionary.
o Sample data: {'1': ['a','b'], '2': ['c','d']}
o Expected Output:
o ac ad bc bd'''

import itertools
d = {"1":["name","city"],"2":["pincode","id"]}
for i in itertools.product(*[d[k]for k in sorted(d.keys())]):
   print(''.join(i))
# Out:
# namepincode
# nameid
# citypincode
# cityid

# %%
#Write a Python program to find the highest 3 values in a dictionary
from heapq import nlargest
my_dict = {'a':500, 'b':5874, 'c': 560,'d':400, 'e':5874, 'f': 20}  
three_largest = nlargest(3, my_dict, key=my_dict.get)
print(three_largest)
# Out:
# ['b', 'e', 'c']

# %%
'''Write a Python program to combine values in python list of dictionaries.
Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount':
300},'
{'item': 'item1', 'amount': 750}]
Expected Output: Counter ({'item1': 1150, 'item2': 300})'''

from collections import Counter
item_list = [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300}, {'item': 'item1', 'amount': 750}]
result = Counter()
for d in item_list:
    result[d['item']] += d['amount']
print(result)
# Out:
# Counter({'item1': 1150, 'item2': 300})

# %%
#Write a Python program to create a dictionary from a string.
from collections import defaultdict, Counter
str1 = 'w3resource' 
my_dict = {}
for letter in str1:
    my_dict[letter] = my_dict.get(letter, 0) + 1
print(my_dict)
# Out:
# {'w': 1, '3': 1, 'r': 2, 'e': 2, 's': 1, 'o': 1, 'u': 1, 'c': 1}

# %%
#Write a Python function to calculate the factorial of a number (a nonnegative integer)
def factorial(n):
    if n == 0:
      return 1
    else:
      return n * factorial(n-1)
n = int(input("input the number \n"))
print(factorial(n))
# Out:
# input the number
# 4
# 24

# %%
#Write a Python function to check whether a number is in a given range
def range_type(n):
  if n in range(3,9):
    print("%s in range"%str(n))
  else:
    print("")
print(range_type(5))
# Out:
# 5 in range
# None

# %%
#Write a Python function to check whether a number is perfect or not.
def perfect_number(n):
    sum = 0
    for x in range(1, n):
        if n % x == 0:
            sum += x
    return sum == n
print(perfect_number(6))
# Out:
# True

# %%
#Write a Python function that checks whether a passed string is palindrome or not
def ispalindrome(string):
  left_pos = 0
  right_pos = len(string) - 1
  while right_pos >= left_pos:
    if not string[left_pos] == string[right_pos]:
      return False
    left_pos += 1
    right_pos -= 1
  return True
print(ispalindrome("fth"))
# Out:
# False

# %%
#How do you perform pattern matching in Python? Explain
import re
phoneNumRegex = re.compile(r'(\d\d\d)-(\d\d\d-\d\d\d\d)')
mo = phoneNumRegex.search('My number is 415-555-4242.')
print(mo.group(1))
# Out:
# 415

# %%
#What is lambda function in python? What we call a function which is incomplete version of a function?
'''A Lambda Function in Python programming is an anonymous function or a function having no name
 syntex (lambda arguments: expression)'''
# Out:
# 'A Lambda Function in Python programming is an anonymous function or a function having no name\n syntex (lambda arguments: expression)'

# %%
#How Many Basic Types Of Functions Are Available In Python?
''' TWO BASIC TYPES There are two basic types of functions: built-in functions and user defined functions. The built-in functions are part of the Python language; for instance dir , len , or abs . The user defined functions are functions created with the def keyword.'''
# Out:
# ' TWO BASIC TYPES There are two basic types of functions: built-in functions and user defined functions. The built-in functions are part of the Python language; for instance dir , len , or abs . The user defined functions are functions created with the def keyword.'

# %%
#How can you pick a random item from a list or tuple?
l = ['hello word']
import random
random.random()
random.randint(1000,9999)
random.choice("hello")
random.randrange(100)
# Out:
# 18

# %%
#How can you pick a random item from a range?
import random 
random.randrange(100)
# Out:
# 80

# %%
#How can you get a random number in python?
import random
random.randint(1000,9999)
# Out:
# 7345

# %%
#How will you set the starting value in generating random numbers?
import random
random.randrange(1000)
print(random.seed())
# Out:
# None

# %%
#How will you randomizes the items of a list in place?
import random 
list = [26,78,7,6]
random.shuffle(list)
print("reshuffle",list)
random.shuffle(list)
print("reshuffle",list)
# Out:
# reshuffle [26, 7, 6, 78]
# reshuffle [6, 7, 78, 26]

# %%
#Write a Python program to read a random line from a file.
import random
def random_line(fname):
  lines = open(fname).read().splitlines()
  return random.choice(lines)
print(random_line("test.txt"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-7f3eecbcb0a8> in <module>()
#       4   lines = open(fname).read().splitlines()
#       5   return random.choice(lines)
# ----> 6 print(random_line("test.txt"))
#       7
#
# <ipython-input-23-7f3eecbcb0a8> in random_line(fname)
#       2 import random
#       3 def random_line(fname):
# ----> 4   lines = open(fname).read().splitlines()
#       5   return random.choice(lines)
#       6 print(random_line("test.txt"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %%
#Write a Python program to convert degree to radian
pi = 22/7
degree = float(input("input degree"))
radian = degree*(pi/180)
print(radian)
# Out:
# input degree34
# 0.5936507936507937

# %%
#Write a Python program to calculate the area of a trapezoid
base1 = 5
base2 = 6
height = float(input("enter the height"))
base1 = float(input("input base1"))
base1 = float(input("input base2"))
area = ((base1 + base2 / 2) * height)
print(area)
# Out:
# enter the height3
# input base13
# input base24
# 21.0

# %%
#Write a Python program to calculate the area of a parallelogram
base = float(input("input base"))
height = float(input("input height"))
area = base * height
print(area)
# Out:
# input base3
# input height5
# 15.0

# %%
#Write a Python program to calculate surface volume and area of a cylinder
pi = 22/7
height = float(input("input volume"))
redian = float(input("input redian"))
volume = pi * redian * redian * height
sur_area = ((2*pi*radian) * height) + ((pi*radian**2)*2)
print("volume is",volume)
print("sur_area is",sur_area)
# Out:
# input volume3
# input redian5
# volume is 235.71428571428572
# sur_area is 13.409777201886046

# %%
#Write a Python program to returns sum of all divisors of a number
def sum_div(number):
    divisors = [1]
    for i in range(2, number):
        if (number % i)==0:
            divisors.append(i)
    return sum(divisors)
print(sum_div(8))
print(sum_div(12))
# Out:
# 7
# 16

# %%
#Write a Python program to find the maximum and minimum numbers from the specified decimal numbers.
from decimal import *
data = list(map(Decimal, '2.45 2.69 2.45 3.45 2.00 0.04 7.25'.split()))
print("maximun :",max(data))
print("minimum :",min(data))
# Out:
# maximun : 7.25
# minimum : 0.04
